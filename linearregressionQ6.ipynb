# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error ,r2_score
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:\Users\scet2\OneDrive\Dokumente\emplinear.csv")

# %%
data
# Out:
#    experience  salary
# 0           5      30
# 1           4      65
# 2           5      35
# 3           2      40
# 4           5      70
# 5           1      80
# 6           3      68
# 7           8      56
# 8           7      49
# 9           3      83

# %%
x=data[['experience']]
y=data[['salary']]

# %%
x
# Out:
#    experience
# 0           5
# 1           4
# 2           5
# 3           2
# 4           5
# 5           1
# 6           3
# 7           8
# 8           7
# 9           3

# %%
y
# Out:
#    salary
# 0      30
# 1      65
# 2      35
# 3      40
# 4      70
# 5      80
# 6      68
# 7      56
# 8      49
# 9      83

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#    experience
# 5           1
# 0           5
# 7           8
# 2           5
# 9           3
# 4           5
# 3           2
# 6           3

# %%
x_test
# Out:
#    experience
# 8           7
# 1           4

# %%
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([[47.86764706],
#        [57.75      ]])

# %%
mse=mean_squared_error(y_test,y_pred)

# %%
mse
# Out:
# 26.92236159169551

# %%
print("Model Coefficients:")
print(f"Coefficient (Slope):{model.coef_[0]}")
print(f"Intercept:{model.intercept_}")
print(f"Mean Squared Error (MSE): {mse}")
# Out:
# Model Coefficients:
# Coefficient (Slope):[-3.29411765]
# Intercept:[70.92647059]
# Mean Squared Error (MSE): 26.92236159169551

# %%
unseen_data=pd.DataFrame({'experience':[5,10,20]})

# %%
predicted_salaries=model.predict(unseen_data)
unseen_data['predicted_salary']=predicted_salaries
print(unseen_data)
# Out:
#    experience  predicted_salary
# 0           5         54.455882
# 1          10         37.985294
# 2          20          5.044118

# %%
all_predicted=model.predict(x)
plt.figure(figsize=(10,6))
plt.scatter(x,y,color='blue',label='Actual Values',alpha=0.7)
plt.scatter(x,all_predicted,color='red',label='Predicted Value',alpha=0.7)
plt.plot(x,all_predicted,color='green',label='Regression Line',linewidth=2)
plt.title('Regression Line:Actual vs Predicted Values(All Sample)')
plt.xlabel('Experience (years)')
plt.ylabel('Salary')
plt.legend()
plt.show()
