# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import load_iris
from sklearn import tree
import matplotlib.pyplot as plt
iris = load_iris()
x = iris.data[:, 2:]
y = iris.target
tree_reg = DecisionTreeRegressor(max_depth=2)
tree_reg.fit(x, y)
tree.plot_tree(tree_reg, feature_names=x)
# Out:
# [Text(0.4, 0.8333333333333334, '[1.4 0.2] <= 0.8\nsquared_error = 0.667\nsamples = 150\nvalue = 1.0'),
#  Text(0.2, 0.5, 'squared_error = 0.0\nsamples = 50\nvalue = 0.0'),
#  Text(0.6, 0.5, '[1.4 0.2] <= 1.75\nsquared_error = 0.25\nsamples = 100\nvalue = 1.5'),
#  Text(0.4, 0.16666666666666666, 'squared_error = 0.084\nsamples = 54\nvalue = 1.093'),
#  Text(0.8, 0.16666666666666666, 'squared_error = 0.021\nsamples = 46\nvalue = 1.978')]
